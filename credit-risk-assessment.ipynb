# %%
import pandas as pd
df = pd.read_csv('data.csv')
# Out:
# C:\Users\CK\AppData\Local\Temp\ipykernel_13268\972680037.py:2: DtypeWarning: Columns (0: desc, 1: verification_status_joint) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan.csv')

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Current                                                601779
# Fully Paid                                             207723
# Charged Off                                             45248
# Late (31-120 days)                                      11591
# Issued                                                   8460
# In Grace Period                                          6253
# Late (16-30 days)                                        2357
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1219
# Does not meet the credit policy. Status:Charged Off       761
# Name: count, dtype: int64
